# %%
from models.qwen import qwen

ocr = qwen()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3353/4210866639.py in <cell line: 0>()
# ----> 1 from models.qwen import qwen
#       2
#       3 ocr = qwen()
#
# ModuleNotFoundError: No module named 'models'
