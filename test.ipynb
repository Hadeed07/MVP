# %%
from pipeline_modules.pipeline import SpinePipeline
from dotenv import load_dotenv
import os
import cv2

load_dotenv()
GOOGLE_BOOKS_API_KEY = os.getenv("GOOGLE_BOOKS_API")

pipeline = SpinePipeline(
    catalog_path=r"Dataset\Books.csv",
    chroma_path=r"chroma_db",
    collection_name="books",
    google_books_api_key=GOOGLE_BOOKS_API_KEY,
)

# %%
# Sample Query
sample_query = """
I'm drawn to books that explain how global power struggles shape everyday life.
I enjoy sharp analysis of international relations, diplomacy, and conflict.
I prefer nonfiction with a strong narrative voice over dry academic writing.
Books that connect historical events to current geopolitical tensions interest me most.
I like authors who aren't afraid to take a clear, well-argued stance.
"""

# Load an image
image = cv2.imread(r'test_images\eng1.jpg')

output = pipeline.results(image, query=sample_query)

print(pipeline.display_results(output))
# Out:
# [WARNING] 2026-08-12 00:05:54,993 [RapidOCR] main.py:132: The text detection result is empty
# YOLO DETECTIONS (CROP NUMBERS)
# --------------------------------------------------------------------------------
# <PIL.Image.Image image mode=RGB size=1200x883>
# ================================================================================
# BOOK DETECTION SUMMARY
# ================================================================================
# Detected Spines : 9
# OCR Results     : 8
# Matched Books   : 8
# Unmatched Books : 1
#
# PER-CROP PIPELINE PROGRESS
# --------------------------------------------------------------------------------
#    Crop Index                                               BBox OCR Status  \
# 0           0  [[1026.8448486328125, 404.0046691894531], [102...    success
# 1           1  [[1020.6884765625, 568.922119140625], [1020.28...    success
# 2           2  [[1022.6697387695312, 799.0770263671875], [102...    success
# 3           3  [[1030.6256103515625, 299.33819580078125], [10...    success
# 4           4  [[1028.0579833984375, 631.4528198242188], [102...    success
# 5           5  [[1042.241943359375, 215.26547241210938], [104...    success
# 6           6  [[1026.3372802734375, 498.0950622558594], [102...    success
# 7           7  [[1018.662353515625, 704.151123046875], [1018....    success
# 8           8  [[1203.7174072265625, 890.2135009765625], [120...     failed
#
#                                             OCR Text  \
# 0           mother | maxim gorky | readings classics
# 1                          the plague | albert camus
# 2    tale of two cities | charles dickens | readings
# 3                farewell to arms | ernest hemingway
# 4                orlando | virginia woolf | readings
# 5  wuthering heights | emily bronté | readingscla...
# 6         the trial | franz kafka | readingsclassics
# 7                         siddhartha | hermann hesse
# 8
#
#                     OCR Scores  \
# 0  [0.99985, 0.99652, 0.99622]
# 1            [0.9999, 0.99951]
# 2  [0.99399, 0.99997, 0.95163]
# 3           [0.98958, 0.99114]
# 4  [0.99989, 0.99039, 0.99298]
# 5   [0.9942, 0.96306, 0.99983]
# 6  [0.99143, 0.99897, 0.99988]
# 7           [0.99993, 0.98659]
# 8                           []
#
#                                          OCR Query Local Match Status  \
# 0             mother maxim gorky readings classics            matched
# 1                          the plague albert camus            matched
# 2      tale of two cities charles dickens readings            matched
# 3                farewell to arms ernest hemingway            matched
# 4                  orlando virginia woolf readings            matched
# 5  wuthering heights emily bronté readingsclassics            matched
# 6           the trial franz kafka readingsclassics            matched
# 7                         siddhartha hermann hesse            matched
# 8                                                       not_attempted
#
#    Local Match Score Google Books Status Google Books Score   Match Source  \
# 0         100.000000          not_needed               None  Local Catalog
# 1         100.000000          not_needed               None  Local Catalog
# 2          88.311688          not_needed               None  Local Catalog
# 3         100.000000          not_needed               None  Local Catalog
# 4         100.000000          not_needed               None  Local Catalog
# 5          86.792453          not_needed               None  Local Catalog
# 6         100.000000          not_needed               None  Local Catalog
# 7         100.000000          not_needed               None  Local Catalog
# 8                NaN       not_attempted               None            NaN
#
#   Final Status                                      Matched Title  \
# 0      matched                                             Mother
# 1      matched                                         The Plague
# 2      matched  A Tale of Two Cities by Charles Dickens (Book ...
# 3      matched                                 A Farewell to Arms
# 4      matched                                            Orlando
# 5      matched                                  Wuthering Heights
# 6      matched                                          The Trial
# 7      matched                                         Siddhartha
# 8    unmatched
#
#      Matched Author           ISBN13  OCR Time (s)  Local Match Time (s)  \
# 0       Maxim Gorky  gb_8a4f63de5438      0.802157              0.021322
# 1      Albert Camus    9780141185132      0.714430              0.001744
# 2  Bright Summaries    9782808018715      0.720697              0.017021
# 3  Ernest Hemingway    9780099910107      0.691957              0.003141
# 4    Virginia Woolf    9780141184272      0.612578              0.002925
# 5      Emily Brontë    9780140620122      0.652946              0.011964
# 6       Franz Kafka    9780099428640      0.651659              0.001265
# 7     Hermann Hesse    9780486114811      0.618164              0.009782
# 8                                         0.546555              0.000001
#
#    Google Books Time (s)  Book Recommendation Time (s)  Crop Total Time (s)
# 0                    0.0                      0.046194             0.869673
# 1                    0.0                      0.002812             0.718987
# 2                    0.0                      0.002782             0.740500
# 3                    0.0                      0.002079             0.697178
# 4                    0.0                      0.001885             0.617388
# 5                    0.0                      0.002665             0.667574
# 6                    0.0                      0.001794             0.654718
# 7                    0.0                      0.001646             0.629592
# 8                    0.0                      0.000000             0.546556
# MATCHED BOOKS
# --------------------------------------------------------------------------------
#    Crop Index                                              Title  \
# 0           0                                             Mother
# 1           1                                         The Plague
# 2           2  A Tale of Two Cities by Charles Dickens (Book ...
# 3           3                                 A Farewell to Arms
# 4           4                                            Orlando
# 5           5                                  Wuthering Heights
# 6           6                                          The Trial
# 7           7                                         Siddhartha
#
#              Author           ISBN13         Source  \
# 0       Maxim Gorky  gb_8a4f63de5438  Local Catalog
# 1      Albert Camus    9780141185132  Local Catalog
# 2  Bright Summaries    9782808018715  Local Catalog
# 3  Ernest Hemingway    9780099910107  Local Catalog
# 4    Virginia Woolf    9780141184272  Local Catalog
# 5      Emily Brontë    9780140620122  Local Catalog
# 6       Franz Kafka    9780099428640  Local Catalog
# 7     Hermann Hesse    9780486114811  Local Catalog
#
#                                          Description  \
# 0  The famous novel of revolutionary conversion a...
# 1  The townspeople of Oran are in the grip of a d...
# 2  Unlock the more more more straightforward side...
# 3  In 1918 Ernest Hemingway went to war, to the '...
# 4  Classic fiction. Orlando, deciding not to grow...
# 5  In a house haunted by memories, the past is ev...
# 6  Written in 1914, The Trial is the terrifying t...
# 7  Classic novel that has inspired generations of...
#
#                                            Thumbnail  \
# 0  http://books.google.com/books/content?id=mAPqD...
# 1  http://books.google.com/books/content?id=uSpDP...
# 2  http://books.google.com/books/content?id=Po6RD...
# 3  http://books.google.com/books/content?id=m68Lh...
# 4  http://books.google.com/books/content?id=fGVgQ...
# 5  http://books.google.com/books/content?id=bK-LR...
# 6  http://books.google.com/books/content?id=pLxfP...
# 7  http://books.google.com/books/content?id=pq_CA...
#
#                                      Recommendations
# 0  [{'ISBN13': '9781400032921', 'Title': 'The Com...
# 1  [{'ISBN13': '9781400042555', 'Title': 'The Pla...
# 2  [{'ISBN13': '9780764586064', 'Title': 'CliffsN...
# 3  [{'ISBN13': '9780306808906', 'Title': 'Hemingw...
# 4  [{'ISBN13': '9780156701600', 'Title': 'Orlando...
# 5  [{'ISBN13': '9780811216371', 'Title': 'October...
# 6  [{'ISBN13': '9780684800707', 'Title': 'The Met...
# 7  [{'ISBN13': '9781476746586', 'Title': 'All the...
# TOP QUERY MATCHES
# --------------------------------------------------------------------------------
#    Crop Index               Title            Author         ISBN13  \
# 0           7          Siddhartha     Hermann Hesse  9780486114811
# 1           3  A Farewell to Arms  Ernest Hemingway  9780099910107
#
#           Source                                        Description  \
# 0  Local Catalog  Classic novel that has inspired generations of...
# 1  Local Catalog  In 1918 Ernest Hemingway went to war, to the '...
#
#                                            Thumbnail  \
# 0  http://books.google.com/books/content?id=pq_CA...
# 1  http://books.google.com/books/content?id=m68Lh...
#
#                                      Recommendations  Query Score  Query Rank
# 0  [{'ISBN13': '9781476746586', 'Title': 'All the...     0.393103           1
# 1  [{'ISBN13': '9780306808906', 'Title': 'Hemingw...     0.389494           2
# PIPELINE TIMING
# --------------------------------------------------------------------------------
#                            Step  Time (s)
# 0                YOLO Detection  0.071429
# 1               YOLO Annotation  0.015356
# 2                Spine Cropping  0.019810
# 3                      RapidOCR  6.011161
# 4        Local Catalog Matching  0.069184
# 5                  Google Books  0.000007
# 6  Book-to-Book Recommendations  0.061885
# 7    User Query Recommendations  0.521364
# 8                Total Pipeline  6.780044
# None
